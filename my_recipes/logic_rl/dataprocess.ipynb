# %%
import pandas as pd
pd.read_parquet('/mnt/code/yehangcheng/verl/recipe/logic_rl/data/test.parquet')
# Out:
#                                                  prompt data_source ability  \
# 0     [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 1     [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 2     [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 3     [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 4     [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# ...                                                 ...         ...     ...
# 4495  [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 4496  [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 4497  [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 4498  [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
# 4499  [{'content': 'You are a helpful assistant. Sol...    kk_logic   logic
#
# ...
